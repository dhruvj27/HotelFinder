# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
import ast

# Load your dataset
df = pd.read_csv('final_merged_sheet.csv')
print("Initial shape:", df.shape)
print("Initial columns:", df.columns.tolist())

# --- 1. DROP UNNECESSARY COLUMNS ---
cols_to_drop = [
    'check_in_time', 'check_out_time', 'phone_number', 'email', 
    'website', 'booking_url', 'data_source', 'address', 
    'Distance_to_Landmark'  # Drop text version, keep Distance_to_Landmark(in_km)
]
df_clean = df.drop(columns=[col for col in cols_to_drop if col in df.columns])
print(f"After dropping columns: {df_clean.shape}")

# --- 2. CLEAN CITY AND STATE COLUMNS ---
# Fill missing city/state values
df_clean['city'] = df_clean['city'].fillna('Unknown')
df_clean['state'] = df_clean['state'].fillna('Unknown')

# Convert to string to ensure consistency
df_clean['city'] = df_clean['city'].astype(str)
df_clean['state'] = df_clean['state'].astype(str)

# --- 3. HANDLE MISSING VALUES ---

# A. Numerical columns - fill with median
numerical_cols = ['rating', 'review_count', 'price_per_night', 'tax', 'guest_rating']
for col in numerical_cols:
    if col in df_clean.columns:
        df_clean[col] = df_clean[col].fillna(df_clean[col].median())

# B. Star rating - keep as Unknown for missing values
df_clean['star_rating'] = df_clean['star_rating'].fillna(-1)  # Use -1 for Unknown
df_clean['star_rating_clean'] = df_clean['star_rating'].apply(
    lambda x: 'Unknown' if x == -1 else str(int(x))
)

# C. Categorical columns
categorical_cols = ['rating_description', 'nearest_landmark', 'price_range', 
                   'location', 'hotel_type', 'room_types']
for col in categorical_cols:
    if col in df_clean.columns:
        df_clean[col] = df_clean[col].fillna('Unknown')

# D. Distance column - fill missing with 'Na', not mean/median/high value
if 'Distance_to_Landmark(in_km)' in df_clean.columns:
    df_clean['Distance_to_Landmark(in_km)'] = df_clean['Distance_to_Landmark(in_km)'].apply(
        lambda x: x if pd.notnull(x) else -1     # since numerical colm keep it -1 for unknown values
    )


# E. Coordinates - fill with India center coordinates
if 'latitude' in df_clean.columns and 'longitude' in df_clean.columns:
    # Option 1: Create a flag for missing coordinates
    df_clean['has_coordinates'] = (~df_clean['latitude'].isna() & ~df_clean['longitude'].isna()).astype(int)
    
    # Option 2: Drop coordinate columns if too many missing values (>50%)
    lat_missing_pct = df_clean['latitude'].isna().mean()
    lon_missing_pct = df_clean['longitude'].isna().mean()
    
    if lat_missing_pct > 0.5 or lon_missing_pct > 0.5:
        print(f"Dropping coordinates due to high missingness: lat={lat_missing_pct:.1%}, lon={lon_missing_pct:.1%}")
        df_clean = df_clean.drop(columns=['latitude', 'longitude'])
    else:
        # If keeping coordinates, fill with median of available coordinates
        df_clean['latitude'] = df_clean['latitude'].fillna(df_clean['latitude'].median())
        df_clean['longitude'] = df_clean['longitude'].fillna(df_clean['longitude'].median())

# F. Handle amenities
if 'amenities' in df_clean.columns:
    df_clean['amenities'] = df_clean['amenities'].fillna('[]')
    
    # Process amenities more carefully
    def safe_eval_amenities(x):
        try:
            if isinstance(x, str) and x.startswith('['):
                return ast.literal_eval(x)
            return []
        except:
            return []
    
    df_clean['amenities_list'] = df_clean['amenities'].apply(safe_eval_amenities)
    
    # Get top 20 most common amenities only to avoid too many columns
    all_amenities = []
    for amenity_list in df_clean['amenities_list']:
        all_amenities.extend(amenity_list)
    
    from collections import Counter
    top_amenities = Counter(all_amenities).most_common(20)
    
    # Create binary columns for top amenities
    for amenity, count in top_amenities:
        col_name = f"amenity_{amenity.replace(' ', '_').replace('-', '_').lower()}"
        df_clean[col_name] = df_clean['amenities_list'].apply(
            lambda x: 1 if amenity in x else 0
        )
    
    # Count total amenities
    df_clean['total_amenities_count'] = df_clean['amenities_list'].apply(len)
    
    # Drop original amenities columns
    df_clean = df_clean.drop(columns=['amenities', 'amenities_list'])

# G. Description - convert to TF-IDF features (limited)
if 'description' in df_clean.columns:
    df_clean['description'] = df_clean['description'].fillna('')
    
    # Only create TF-IDF if we have descriptions
    if df_clean['description'].str.len().sum() > 0:
        tfidf = TfidfVectorizer(max_features=30, stop_words='english', min_df=5)
        description_tfidf = tfidf.fit_transform(df_clean['description'])
        
        # Add TF-IDF features
        feature_names = [f"desc_{name}" for name in tfidf.get_feature_names_out()]
        tfidf_df = pd.DataFrame(description_tfidf.toarray(), 
                               columns=feature_names, 
                               index=df_clean.index)
        df_clean = pd.concat([df_clean, tfidf_df], axis=1)
    
    df_clean = df_clean.drop(columns=['description'])

# H. Data quality score - keep as is if exists
if 'data_quality_score' in df_clean.columns:
    df_clean['data_quality_score'] = df_clean['data_quality_score'].fillna(df_clean['data_quality_score'].median())

# --- 4. ENCODE CATEGORICAL VARIABLES (SMART APPROACH) ---

# Create a dictionary to store label encoders
label_encoders = {}

# Label encoding for high cardinality
for col in high_cardinality_cols:
    if col in df_clean.columns:
        le = LabelEncoder()
        df_clean[f'{col}_encoded'] = le.fit_transform(df_clean[col].astype(str))
        
        # Save the encoder for later reference
        label_encoders[col] = le

# Now you can access the mappings
print("State encoding mapping:")
for i, state in enumerate(label_encoders['state'].classes_):
    print(f"{i}: {state}")

print("\nCity encoding mapping:")
for i, city in enumerate(label_encoders['city'].classes_):
    print(f"{i}: {city}")

print("\nHotel name encoding mapping (first 10):")
for i, hotel in enumerate(label_encoders['hotel_name'].classes_[:10]):
    print(f"{i}: {hotel}")

# For high cardinality categoricals like city/state, use label encoding
# For low cardinality ones, use one-hot encoding

high_cardinality_cols = ['city', 'state', 'hotel_name']
low_cardinality_cols = ['rating_description', 'nearest_landmark', 'price_range', 
                       'location', 'hotel_type', 'room_types', 'star_rating_clean']

# Label encoding for high cardinality
for col in high_cardinality_cols:
    if col in df_clean.columns:
        le = LabelEncoder()
        df_clean[f'{col}_encoded'] = le.fit_transform(df_clean[col].astype(str))

# One-hot encoding for low cardinality (limit categories)
for col in low_cardinality_cols:
    if col in df_clean.columns:
        # Limit to top 10 categories to avoid explosion
        top_categories = df_clean[col].value_counts().head(10).index
        df_clean[col] = df_clean[col].apply(
            lambda x: x if x in top_categories else 'Other'
        )
        
        # One-hot encode
        dummies = pd.get_dummies(df_clean[col], prefix=col)
        df_clean = pd.concat([df_clean, dummies], axis=1)

# Drop original categorical columns
categorical_to_drop = high_cardinality_cols + low_cardinality_cols + ['star_rating']
df_clean = df_clean.drop(columns=[col for col in categorical_to_drop if col in df_clean.columns])

# --- 5. SCALE NUMERICAL FEATURES ---
# Identify numerical columns for scaling
numerical_cols_to_scale = []
for col in df_clean.columns:
    if df_clean[col].dtype in ['float64', 'int64'] and not col.endswith('_encoded'):
        # Skip binary columns (0s and 1s)
        if not (df_clean[col].isin([0, 1]).all()):
            numerical_cols_to_scale.append(col)

print(f"Numerical columns to scale: {numerical_cols_to_scale}")

if numerical_cols_to_scale:
    scaler = StandardScaler()
    df_clean[numerical_cols_to_scale] = scaler.fit_transform(df_clean[numerical_cols_to_scale])

# --- 6. FINAL CLEANUP ---
# Remove any constant columns
df_clean = df_clean.loc[:, df_clean.nunique() > 1]

print(f"Final dataset shape: {df_clean.shape}")
print(f"Final columns: {len(df_clean.columns)}")

# Display info about the cleaned dataset
print("\nDataset Info:")
print(df_clean.info())

print(f"\nMissing values per column:")
missing_counts = df_clean.isnull().sum()
print(missing_counts[missing_counts > 0])

print(f"\nData types:")
print(df_clean.dtypes.value_counts())

# Save the preprocessed data
df_clean.to_csv('preprocessed_hotel_data_final.csv', index=False)
print("\nPreprocessed data saved as 'preprocessed_hotel_data_final.csv'")

# Show sample of the processed data
print(f"\nSample of processed data:")
print(df_clean.head())
# Out:
# Initial shape: (4632, 30)
# Initial columns: ['hotel_name', 'rating', 'rating_description', 'review_count', 'star_rating', 'location', 'nearest_landmark', 'Distance_to_Landmark', 'Distance_to_Landmark(in_km)', 'price_per_night', 'tax', 'city', 'state', 'address', 'price_range', 'latitude', 'longitude', 'amenities', 'hotel_type', 'phone_number', 'email', 'website', 'booking_url', 'guest_rating', 'description', 'check_in_time', 'check_out_time', 'room_types', 'data_source', 'data_quality_score']
# After dropping columns: (4632, 21)
# State encoding mapping:
# 0: Arunachal Pradesh
# 1: Assam
# 2: Delhi
# 3: Goa
# 4: Gujarat
# 5: Haryana
# 6: Himachal Pradesh
# 7: Karnataka
# 8: Kerala
# 9: Madhya Pradesh
# 10: Maharashtra
# 11: Rajasthan
# 12: Tamil Nadu
# 13: Telangana
# 14: Uttar Pradesh
# 15: West Bengal
#
# City encoding mapping:
# 0: Agra
# 1: Ahmedabad
# 2: Bangalore
# 3: Bhopal
# 4: Chennai
# 5: Dispur
# 6: Faridabad
# 7: Gandhinagar
# 8: Ghaziabad
# 9: Hyderabad
# 10: Indore
# 11: Itanagar
# 12: Jaipur
# 13: Kanpur
# 14: Kolkata
# 15: Lucknow
# 16: Mumbai
# 17: Nagpur
# 18: New Delhi
# 19: Panaji
# 20: Pune
# 21: Shimla
# 22: Surat
# 23: Thiruvananthapuram
# 24: Vadodara
#
# Hotel name encoding mapping (first 10):
# 0: "JADE by the Ocean" luxury Villa by Lujo Stays
# 1: #224, 1st main, 9th Cross, Aanam Enclave, Ashwathnagar
# 2: 10 Calangute A Boutique Hotel
# 3: 2BR Candolim Villa 10
# 4: 2BR Candolim Villa 9
# 5: 37th Crescent Hotel
# 6: 3BR Beach Villa Candolim with private pool
# 7: 3BR Luxury Penthouse Villa Sky with Private Pool
# 8: 3BR Luxury Villa May with Private Pool
# 9: 3BR Luxury Villa Ray with Private Pool
# Numerical columns to scale: ['rating', 'review_count', 'Distance_to_Landmark(in_km)', 'price_per_night', 'tax', 'latitude', 'longitude', 'guest_rating', 'data_quality_score', 'desc_access', 'desc_accommodation', 'desc_amenities', 'desc_bhopal', 'desc_budget', 'desc_business', 'desc_city', 'desc_comfortable', 'desc_convenient', 'desc_excellent', 'desc_gandhinagar', 'desc_ghaziabad', 'desc_heart', 'desc_hotel', 'desc_indore', 'desc_itanagar', 'desc_kanpur', 'desc_located', 'desc_lucknow', 'desc_luxury', 'desc_modern', 'desc_nagpur', 'desc_offering', 'desc_popular', 'desc_premium', 'desc_quality', 'desc_service', 'desc_surat', 'desc_vadodara']
# Final dataset shape: (4632, 99)
# Final columns: 99
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4632 entries, 0 to 4631
# Data columns (total 99 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   rating                                                                  4632 non-null   float64
#  1   review_count                                                            4632 non-null   float64
#  2   Distance_to_Landmark(in_km)                                             4632 non-null   float64
#  3   price_per_night                                                         4632 non-null   float64
#  4   tax                                                                     4632 non-null   float64
#  5   latitude                                                                4632 non-null   float64
#  6   longitude                                                               4632 non-null   float64
#  7   guest_rating                                                            4632 non-null   float64
#  8   data_quality_score                                                      4632 non-null   float64
#  9   has_coordinates                                                         4632 non-null   int64
#  10  desc_access                                                             4632 non-null   float64
#  11  desc_accommodation                                                      4632 non-null   float64
#  12  desc_amenities                                                          4632 non-null   float64
#  13  desc_bhopal                                                             4632 non-null   float64
#  14  desc_budget                                                             4632 non-null   float64
#  15  desc_business                                                           4632 non-null   float64
#  16  desc_city                                                               4632 non-null   float64
#  17  desc_comfortable                                                        4632 non-null   float64
#  18  desc_convenient                                                         4632 non-null   float64
#  19  desc_excellent                                                          4632 non-null   float64
#  20  desc_gandhinagar                                                        4632 non-null   float64
#  21  desc_ghaziabad                                                          4632 non-null   float64
#  22  desc_heart                                                              4632 non-null   float64
#  23  desc_hotel                                                              4632 non-null   float64
#  24  desc_indore                                                             4632 non-null   float64
#  25  desc_itanagar                                                           4632 non-null   float64
#  26  desc_kanpur                                                             4632 non-null   float64
#  27  desc_located                                                            4632 non-null   float64
#  28  desc_lucknow                                                            4632 non-null   float64
#  29  desc_luxury                                                             4632 non-null   float64
#  30  desc_modern                                                             4632 non-null   float64
#  31  desc_nagpur                                                             4632 non-null   float64
#  32  desc_offering                                                           4632 non-null   float64
#  33  desc_popular                                                            4632 non-null   float64
#  34  desc_premium                                                            4632 non-null   float64
#  35  desc_quality                                                            4632 non-null   float64
#  36  desc_service                                                            4632 non-null   float64
#  37  desc_surat                                                              4632 non-null   float64
#  38  desc_vadodara                                                           4632 non-null   float64
#  39  city_encoded                                                            4632 non-null   int64
#  40  state_encoded                                                           4632 non-null   int64
#  41  hotel_name_encoded                                                      4632 non-null   int64
#  42  rating_description_Average                                              4632 non-null   bool
#  43  rating_description_Excellent                                            4632 non-null   bool
#  44  rating_description_Good                                                 4632 non-null   bool
#  45  rating_description_Poor                                                 4632 non-null   bool
#  46  rating_description_Unknown                                              4632 non-null   bool
#  47  rating_description_Very Good                                            4632 non-null   bool
#  48  nearest_landmark_Chennai Airport                                        4632 non-null   bool
#  49  nearest_landmark_Indira Gandhi International Airport                    4632 non-null   bool
#  50  nearest_landmark_MG Road                                                4632 non-null   bool
#  51  nearest_landmark_Netaji Subhash Chandra Bose International Airport      4632 non-null   bool
#  52  nearest_landmark_Other                                                  4632 non-null   bool
#  53  nearest_landmark_Park Street                                            4632 non-null   bool
#  54  nearest_landmark_T1 - Chhatrapati Shivaji International Airport         4632 non-null   bool
#  55  nearest_landmark_T1 - Delhi Airport (IGI Airport)                       4632 non-null   bool
#  56  nearest_landmark_T2 - Chhatrapati Shivaji International Airport         4632 non-null   bool
#  57  nearest_landmark_Unknown                                                4632 non-null   bool
#  58  nearest_landmark_city centre                                            4632 non-null   bool
#  59  price_range_Budget (Under ₹2000)                                        4632 non-null   bool
#  60  price_range_Luxury (Above ₹10000)                                       4632 non-null   bool
#  61  price_range_Mid-range (₹2000-5000)                                      4632 non-null   bool
#  62  price_range_Premium (₹5000-10000)                                       4632 non-null   bool
#  63  price_range_Unknown                                                     4632 non-null   bool
#  64  location_Aerocity                                                       4632 non-null   bool
#  65  location_Andheri East                                                   4632 non-null   bool
#  66  location_Connaught Place                                                4632 non-null   bool
#  67  location_Gachibowli                                                     4632 non-null   bool
#  68  location_Hitech City                                                    4632 non-null   bool
#  69  location_Koramangala                                                    4632 non-null   bool
#  70  location_Mahipalpur                                                     4632 non-null   bool
#  71  location_Near Mumbai Airport                                            4632 non-null   bool
#  72  location_Other                                                          4632 non-null   bool
#  73  location_Salt Lake City                                                 4632 non-null   bool
#  74  location_Unknown                                                        4632 non-null   bool
#  75  hotel_type_Budget                                                       4632 non-null   bool
#  76  hotel_type_Business                                                     4632 non-null   bool
#  77  hotel_type_Luxury                                                       4632 non-null   bool
#  78  hotel_type_Premium                                                      4632 non-null   bool
#  79  hotel_type_Resort                                                       4632 non-null   bool
#  80  hotel_type_Unknown                                                      4632 non-null   bool
#  81  room_types_Other                                                        4632 non-null   bool
#  82  room_types_Standard Room, Deluxe Room                                   4632 non-null   bool
#  83  room_types_Standard Room, Deluxe Room, Business Suite                   4632 non-null   bool
#  84  room_types_Standard Room, Deluxe Room, Business Suite, Conference Room  4632 non-null   bool
#  85  room_types_Standard Room, Deluxe Room, Conference Room                  4632 non-null   bool
#  86  room_types_Standard Room, Deluxe Room, Executive Room                   4632 non-null   bool
#  87  room_types_Standard Room, Deluxe Room, Executive Room, Conference Room  4632 non-null   bool
#  88  room_types_Standard Room, Deluxe Room, Family Room                      4632 non-null   bool
#  89  room_types_Standard Room, Deluxe Room, Suite, Executive Room            4632 non-null   bool
#  90  room_types_Standard Room, Deluxe Room, Twin Room                        4632 non-null   bool
#  91  room_types_Unknown                                                      4632 non-null   bool
#  92  star_rating_clean_0                                                     4632 non-null   bool
#  93  star_rating_clean_1                                                     4632 non-null   bool
#  94  star_rating_clean_2                                                     4632 non-null   bool
#  95  star_rating_clean_3                                                     4632 non-null   bool
#  96  star_rating_clean_4                                                     4632 non-null   bool
#  97  star_rating_clean_5                                                     4632 non-null   bool
#  98  star_rating_clean_Unknown                                               4632 non-null   bool
# dtypes: bool(57), float64(38), int64(4)
# memory usage: 1.7 MB
# None
#
# Missing values per column:
# Series([], dtype: int64)
#
# Data types:
# bool       57
# float64    38
# int64       4
# Name: count, dtype: int64
#
# Preprocessed data saved as 'preprocessed_hotel_data_final.csv'
#
# Sample of processed data:
#      rating  review_count  Distance_to_Landmark(in_km)  price_per_night  \
# 0 -0.732956      4.327100                    -0.156256         0.928630
# 1  0.021332      2.019873                    -0.156256        -1.033653
# 2  3.038487      0.990567                     1.149984         1.684325
# 3  0.021332      5.374994                     0.523757        -0.762211
# 4  0.021332      3.285014                    -0.156256        -0.705526
#
#         tax  latitude  longitude  guest_rating  data_quality_score  \
# 0  8.330067  -0.12861  -0.031971      0.025237            0.014695
# 1 -0.936168  -0.12861  -0.031971      0.025237            0.014695
# 2 -0.067626  -0.12861  -0.031971      0.025237            0.014695
# 3  1.145105  -0.12861  -0.031971      0.025237            0.014695
# 4  1.661390  -0.12861  -0.031971      0.025237            0.014695
#
#    has_coordinates  ...  \
# 0                0  ...
# 1                0  ...
# 2                0  ...
# 3                0  ...
# 4                0  ...
#
#    room_types_Standard Room, Deluxe Room, Suite, Executive Room  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    room_types_Standard Room, Deluxe Room, Twin Room  room_types_Unknown  \
# 0                                             False                True
# 1                                             False                True
# 2                                             False                True
# 3                                             False                True
# 4                                             False                True
#
#    star_rating_clean_0  star_rating_clean_1  star_rating_clean_2  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#    star_rating_clean_3  star_rating_clean_4  star_rating_clean_5  \
# 0                False                False                 True
# 1                False                 True                False
# 2                False                False                 True
# 3                False                False                 True
# 4                False                 True                False
#
#    star_rating_clean_Unknown
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
#
# [5 rows x 99 columns]
